# %%
# pip install transformers

# %%
from transformers import TrOCRProcessor, VisionEncoderDecoderModel, XLMRobertaForCausalLM, AutoTokenizer, GenerationConfig
from transformers import EarlyStoppingCallback, TrainerCallback

# %%
model_dir = "workspace/github/vit_xlm_roberta/outputs/checkpoint-71000"

# %%
model = VisionEncoderDecoderModel.from_pretrained(
    "/workspace/github/vit_xlm_roberta/outputs/checkpoint-71000"
)
# Out:
# Some weights of the model checkpoint at /workspace/github/vit_xlm_roberta/outputs/checkpoint-71000 were not used when initializing VisionEncoderDecoderModel: ['decoder.lm_head.bias', 'decoder.lm_head.dense.bias', 'decoder.lm_head.dense.weight', 'decoder.lm_head.layer_norm.bias', 'decoder.lm_head.layer_norm.weight', 'decoder.roberta.embeddings.LayerNorm.bias', 'decoder.roberta.embeddings.LayerNorm.weight', 'decoder.roberta.embeddings.position_embeddings.weight', 'decoder.roberta.embeddings.token_type_embeddings.weight', 'decoder.roberta.embeddings.word_embeddings.weight', 'decoder.roberta.encoder.layer.0.attention.output.LayerNorm.bias', 'decoder.roberta.encoder.layer.0.attention.output.LayerNorm.weight', 'decoder.roberta.encoder.layer.0.attention.output.dense.bias', 'decoder.roberta.encoder.layer.0.attention.output.dense.weight', 'decoder.roberta.encoder.layer.0.attention.self.key.bias', 'decoder.roberta.encoder.layer.0.attention.self.key.weight', 'decoder.roberta.encoder.layer.0.att
# ...

# %%
model.generation_config
# Out:
# GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 2,
#   "pad_token_id": 1,
#   "repetition_penalty": 1.1,
#   "use_cache": false
# }
